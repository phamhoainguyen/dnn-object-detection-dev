# %% [markdown]
# ## 1. Install necessary libraries

# %%
# !pip install fiftyone

# %% [markdown]
# ## 2. Import libraries

# %%
import fiftyone as fo
import fiftyone.zoo as foz
# Out:
# NumExpr defaulting to 2 threads.
# Migrating database to v0.16.5

# %% [markdown]
# ## 3. Declare constant values

# %% [markdown]
# ## 4. Download coco dataset

# %%
dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="validation",
    max_samples=50,
    shuffle=True,
)

session = fo.launch_app(dataset)
# Out:
# Downloading split 'validation' to '/root/fiftyone/coco-2017/validation' if necessary
# Downloading annotations to '/root/fiftyone/coco-2017/tmp-download/annotations_trainval2017.zip'
#  100% |██████|    1.9Gb/1.9Gb [5.7s elapsed, 0s remaining, 372.6Mb/s]
# Extracting annotations to '/root/fiftyone/coco-2017/raw/instances_val2017.json'
# Downloading 50 images
#  100% |████████████████████| 50/50 [10.0s elapsed, 0s remaining, 5.2 images/s]
# Writing annotations for 50 downloaded samples to '/root/fiftyone/coco-2017/validation/labels.json'
# Dataset info written to '/root/fiftyone/coco-2017/info.json'
# Loading 'coco-2017' split 'validation'
#  100% |███████████████████| 50/50 [358.5ms elapsed, 0s remaining, 142.8 samples/s]
# Dataset 'coco-2017-validation-50' created
# <style>
#
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-1ec330dc-bcd3-444a-b93d-a28d8cf6f533 {
#   position: relative;
#   height: px;
#   display: block !important;
# }
# #foactivate-1ec330dc-bcd3-444a-b93d-a28d8cf6f533 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-1ec330dc-bcd3-444a-b93d-a28d8cf6f533:focus {
#   outline: none;
# }
# #fooverlay-1ec330dc-bcd3-444a-b93d-a28d8cf6f533 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
# <div id="focontainer-1ec330dc-bcd3-444a-b93d-a28d8cf6f533" style="display: none;">
#    <div id="fooverlay-1ec330dc-bcd3-444a-b93d-a28d8cf6f533">
#       <button id="foactivate-1ec330dc-bcd3-444a-b93d-a28d8cf6f533" >Activate</button>
#    </div>
# </div>

# %%
type(dataset)
# Out:
# fiftyone.core.dataset.Dataset
